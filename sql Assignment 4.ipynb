# %% [markdown]
# Q-1. Write an SQL query to print the FIRST_NAME from Worker table after replacing ‘a’ with ‘A’.
#
# Ans. Select replace(firstname, 'a', 'A') as firstname from Worker_fil;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-2. Write an SQL query to print all Worker details from the Worker table order by FIRST_NAME Ascending and DEPARTMENT Descending.
#
# Ans. select * from worker_fil
#         order by firstname asc, department desc;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-3. Write an SQL query to fetch the names of workers who earn the highest salary.
#
#
# Ans. select salary as maxsalary, firstname, lastname from worker_fil order by salary desc;

# %% [markdown]
# ![image.png](attachment:image.png)
