# %%
import pandas as pd
import openpyxl

# %%
wb = openpyxl.Workbook()

# %%
sheet =wb.active

# %%
b1 = sheet.cell(row = 1, column = 1)

# %%
b1.value= 'Mohit'

# %%
b2 = sheet.cell(row= 1 , column = 2)

# %%
b2.value = 'Singh'

# %%
b3 = sheet['A2']
b3.value = "RAHUL"

# %%
b4 = sheet['B2']
b4.value = "RAI"

# %%
wb.save("C:\\Users\\Praveen Sharma\\Downloads\\test.xlsx")

# %%
df = pd.read_excel("C:\\Users\\Praveen Sharma\\Downloads\\test.xlsx")

# %%
df
# Out:
#    Mohit Singh
# 0  RAHUL   RAI

# %%
df = pd.read_excel('C:\\Users\\Praveen Sharma\\Downloads\\EmployeeSampleData\\Employee Sample Data.xlsx')

# %%
df.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %%
###Convert data into different-2 sheets and share one excel

df2 = df[df['Job Title'] == 'Sr. Manger']

# %%
df2
# Out:
#        EEID       Full Name   Job Title       Department  \
# 0    E02387     Emily Davis  Sr. Manger               IT
# 10   E00591    Savannah Ali  Sr. Manger  Human Resources
# 13   E04239    Everleigh Ng  Sr. Manger          Finance
# 17   E00884    Camila Silva  Sr. Manger        Marketing
# 20   E03680  Elias Alvarado  Sr. Manger               IT
# ..      ...             ...         ...              ...
# 950  E02888    Elijah Ramos  Sr. Manger               IT
# 956  E03168         Nora Le  Sr. Manger               IT
# 971  E03778         Luke Vu  Sr. Manger        Marketing
# 985  E00156   Madelyn Scott  Sr. Manger               IT
# 990  E01578    Anthony Hong  Sr. Manger               IT
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# 10            Manufacturing  Female      Asian   36 2009-02-11         157333
# ...

# %%
df3 = df[df['Job Title'] == 'Sr. Analyst']

# %%
df3
# Out:
#        EEID         Full Name    Job Title  Department        Business Unit  \
# 4    E01639         Austin Vo  Sr. Analyst     Finance        Manufacturing
# 9    E03838   Madeline Walker  Sr. Analyst     Finance  Speciality Products
# 14   E03496       Robert Yang  Sr. Analyst  Accounting  Speciality Products
# 61   E00502   Natalia Salazar  Sr. Analyst  Accounting        Manufacturing
# 65   E03906  Piper Richardson  Sr. Analyst       Sales            Corporate
# ..      ...               ...          ...         ...                  ...
# 927  E04335      Parker Allen  Sr. Analyst       Sales  Speciality Products
# 959  E01488        Stella Lai  Sr. Analyst  Accounting        Manufacturing
# 981  E04598     Violet Garcia  Sr. Analyst   Marketing  Speciality Products
# 995  E03094      Wesley Young  Sr. Analyst   Marketing  Speciality Products
# 998  E02521       Lily Nguyen  Sr. Analyst     Finance  Speciality Products
#
# ...

# %%
df4 = df[df['Job Title'] == 'Director']

# %%
df4
# Out:
#        EEID          Full Name Job Title Department           Business Unit  \
# 2    E02572       Luna Sanders  Director    Finance     Speciality Products
# 16   E00163       Bella Powell  Director    Finance  Research & Development
# 18   E04116       David Barnes  Director         IT               Corporate
# 19   E04625          Adam Dang  Director      Sales  Research & Development
# 21   E04732         Eva Rivera  Director      Sales           Manufacturing
# ..      ...                ...       ...        ...                     ...
# 984  E02191          Maria Sun  Director      Sales               Corporate
# 986  E03349         Dylan Chin  Director    Finance               Corporate
# 988  E00005   Riley Washington  Director      Sales     Speciality Products
# 993  E04762  Audrey Richardson  Director         IT           Manufacturing
# 997  E04398        Oliver Yang  Director  Marketing     Speciality Products
#
# ...

# %%
with pd.ExcelWriter("C:\\Users\\Praveen Sharma\\Downloads\\EmployeeSampleData\\excelfile.xlsx") as writer:
    df2.to_excel(writer, sheet_name = 'Sr Manager data')
    df3.to_excel(writer, sheet_name = 'Sr analyst')
    df4.to_excel(writer, sheet_name = 'director')

# %%
df = pd.read_excel("C:\\Users\\Praveen Sharma\\Downloads\\EmployeeSampleData\\excelfile.xlsx", sheet_name= 'Sr Manager data')

# %%
df.head()
# Out:
#    Unnamed: 0    EEID       Full Name   Job Title       Department  \
# 0           0  E02387     Emily Davis  Sr. Manger               IT
# 1          10  E00591    Savannah Ali  Sr. Manger  Human Resources
# 2          13  E04239    Everleigh Ng  Sr. Manger          Finance
# 3          17  E00884    Camila Silva  Sr. Manger        Marketing
# 4          20  E03680  Elias Alvarado  Sr. Manger               IT
#
#             Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female     Black   55 2016-04-08         141604
# 1           Manufacturing  Female     Asian   36 2009-02-11         157333
# 2  Research & Development  Female     Asian   51 2021-06-10         146742
# 3     Speciality Products  Female    Latino   64 2003-12-01         154828
# 4           Manufacturing    Male    Latino   56 2012-01-09         146140
#
#    Bonus %        Country      City  Exit Date
# 0     0.15  United States   Seattle 2021-10-16
# ...

# %%
df2 = pd.read_excel("C:\\Users\\Praveen Sharma\\Downloads\\EmployeeSampleData\\excelfile.xlsx", sheet_name= 'Sr analyst')

# %%
df2.head()
# Out:
#    Unnamed: 0    EEID         Full Name    Job Title  Department  \
# 0           4  E01639         Austin Vo  Sr. Analyst     Finance
# 1           9  E03838   Madeline Walker  Sr. Analyst     Finance
# 2          14  E03496       Robert Yang  Sr. Analyst  Accounting
# 3          61  E00502   Natalia Salazar  Sr. Analyst  Accounting
# 4          65  E03906  Piper Richardson  Sr. Analyst       Sales
#
#          Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0        Manufacturing    Male      Asian   55 1995-11-20          95409
# 1  Speciality Products  Female  Caucasian   34 2018-06-13          77203
# 2  Speciality Products    Male      Asian   31 2017-11-04          97078
# 3        Manufacturing  Female     Latino   44 2019-01-02          74691
# 4            Corporate  Female  Caucasian   38 2008-01-27          80024
#
#    Bonus %        Country      City  Exit Date
# 0        0  United States   Phoenix        NaT
# ...

# %%
df3 = pd.read_excel("C:\\Users\\Praveen Sharma\\Downloads\\EmployeeSampleData\\excelfile.xlsx", sheet_name= 'director')

# %%
df3.head()
# Out:
#    Unnamed: 0    EEID     Full Name Job Title Department  \
# 0           2  E02572  Luna Sanders  Director    Finance
# 1          16  E00163  Bella Powell  Director    Finance
# 2          18  E04116  David Barnes  Director         IT
# 3          19  E04625     Adam Dang  Director      Sales
# 4          21  E04732    Eva Rivera  Director      Sales
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 1  Research & Development  Female      Black   65 2002-03-04         175837
# 2               Corporate    Male  Caucasian   64 2013-11-03         186503
# 3  Research & Development    Male      Asian   45 2002-07-09         166331
# 4           Manufacturing  Female     Latino   36 2021-04-02         151703
#
#    Bonus %        Country       City Exit Date
# 0     0.20  United States    Chicago       NaT
# 1     0.20  United States    Phoenix       NaT
# ...
