# %% [markdown]
# Q-1. Write an SQL query to print details of the Workers who have joined in Feb’2014.
#
# Ans. select * from worker_fil where joindate = 'feb';

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-2. Write an SQL query to fetch duplicate records having matching data in some fields of a table.
#
# Ans. select salary, joindate, count(*) as cnt
# from worker_fil
# group by salary, joindate
# having count(*)>1;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-3. How to remove duplicate rows from Employees table.
#
# Ans. 1. SELECT email, count(email) from contacts group by email having count(email)>1;
#
# 2. DELETE t1 FROM contacts t1
# INNER JOIN contacts t2
# WHERE
# t1.id < t2.id AND
# t1.email = t2.email;

# %% [markdown]
# ![image.png](attachment:image.png)
