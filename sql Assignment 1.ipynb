# %% [markdown]
# Q-1. Write an SQL query to fetch “FIRST_NAME” from Worker table using the alias name as <WORKER_NAME>.
# Ans. select firstname from worker_fil;
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-2. Write an SQL query to fetch unique values of DEPARTMENT from Worker table.
# Ans. select department from worker_fil;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q-3. Write an SQL query to show the last 5 record from a tab
# Ans. select * from worker_fil order by age desc limit 5;

# %% [markdown]
# ![image.png](attachment:image.png)
